# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
numpyDizisi1 = np.linspace(0,10,20)

# %%
numpyDizisi2 = numpyDizisi1 ** 2

# %%
(benimFigur,benimEksen) = pyt.subplots()

# %% [markdown]
# ## Color Seçenekleri

# %%
benimEksen.plot(numpyDizisi1, numpyDizisi2,"g")

# %%
(benimFigur,benimEksen) = pyt.subplots()
benimEksen.plot(numpyDizisi1, numpyDizisi2,"g")

# %%
(benimFigur,benimEksen) = pyt.subplots()
benimEksen.plot(numpyDizisi1, numpyDizisi2,"g")
benimEksen.plot(numpyDizisi2,numpyDizisi1,"b")
benimEksen.plot(numpyDizisi2,numpyDizisi1*2, color="#A40FCA")

# %%
(benimFigur,benimEksen) = pyt.subplots()
benimEksen.plot(numpyDizisi1, numpyDizisi2,"g")
benimEksen.plot(numpyDizisi2,numpyDizisi1,"b")
benimEksen.plot(numpyDizisi2,numpyDizisi1*2, color="#A40FCA", alpha=0.3)

# %%
(yeniFigur,yeniEksen) = plt.subplots()
yeniEksen.plot(numpyDizisi1,numpyDizisi1 +2, color = "blue")

# %%
(yeniFigur,yeniEksen) = plt.subplots()
yeniEksen.plot(numpyDizisi1,numpyDizisi1 +2, color = "blue")
yeniEksen.plot(numpyDizisi1,numpyDizisi1 +3, color = "yellow")

# %% [markdown]
# ## Kalınlık

# %%
(yeniFigur,yeniEksen) = plt.subplots()
yeniEksen.plot(numpyDizisi1,numpyDizisi1 +2, color = "blue", linewidth = 8.0)
yeniEksen.plot(numpyDizisi1,numpyDizisi1 +3, color = "yellow", linewidth = 3.1)

# %% [markdown]
# ### Çizgi Stilleri

# %%
(yeniFigur,yeniEksen) = plt.subplots()
yeniEksen.plot(numpyDizisi1,numpyDizisi1 +2, color = "blue", linewidth = 8.0)
yeniEksen.plot(numpyDizisi1,numpyDizisi1 +3, color = "yellow", linewidth = 3.1)
yeniEksen.plot(numpyDizisi1, numpyDizisi1 + 4, color = "green", linestyle = "-")

# %%
(yeniFigur,yeniEksen) = plt.subplots()
yeniEksen.plot(numpyDizisi1,numpyDizisi1 +2, color = "blue", linewidth = 8.0)
yeniEksen.plot(numpyDizisi1,numpyDizisi1 +3, color = "yellow", linewidth = 3.1)
yeniEksen.plot(numpyDizisi1, numpyDizisi1 + 4, color = "green", linestyle = "--")

# %%
(yeniFigur,yeniEksen) = plt.subplots()
yeniEksen.plot(numpyDizisi1,numpyDizisi1 +2, color = "blue", linewidth = 8.0)
yeniEksen.plot(numpyDizisi1,numpyDizisi1 +3, color = "yellow", linewidth = 3.1)
yeniEksen.plot(numpyDizisi1, numpyDizisi1 + 4, color = "green", linestyle = ":")

# %%
(yeniFigur,yeniEksen) = plt.subplots()
yeniEksen.plot(numpyDizisi1,numpyDizisi1 +2, color = "blue", linewidth = 8.0)
yeniEksen.plot(numpyDizisi1,numpyDizisi1 +3, color = "yellow", linewidth = 3.1)
yeniEksen.plot(numpyDizisi1, numpyDizisi1 + 4, color = "green", linestyle = "-.")

# %% [markdown]
# ## Veri Marklama (Noktalama)

# %%
(yeniFigur,yeniEksen) = plt.subplots()
yeniEksen.plot(numpyDizisi1,numpyDizisi1 +2, color = "blue", linewidth = 8.0)
yeniEksen.plot(numpyDizisi1,numpyDizisi1 +3, color = "yellow", linewidth = 3.1)
yeniEksen.plot(numpyDizisi1, numpyDizisi1 + 4, color = "green", linestyle = "-.")

yeniEksen.plot(numpyDizisi1,numpyDizisi1+6, color = "#000000",linestyle="-",marker="o", markersize =10 ,markerfacecolor="red")

# %% [markdown]
# ## Diğer Tablo Türleri

# %% [markdown]
# ## Scatter

# %%
plt.scatter(numpyDizisi1,numpyDizisi2)

# %% [markdown]
# ## Histogram

# %%
yeniDizi = np.random.randint(0,100,50)

# %%
plt.hist(yeniDizi)
# Out:
# (array([4., 5., 7., 5., 4., 7., 3., 5., 3., 7.]),
#  array([ 0. ,  9.7, 19.4, 29.1, 38.8, 48.5, 58.2, 67.9, 77.6, 87.3, 97. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Boxplot

# %%
plt.boxplot(yeniDizi)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fe8e00dc910>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fe8e00dcee0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fe8e00dc6a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fe8e00ed4c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fe8e00ed790>],
#  'means': []}

# %%
plt.boxplot(yeniDizi*2)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fe90bcd8c10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fe90bceb190>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fe90bcd8940>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fe90bceb640>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fe90bceb910>],
#  'means': []}
