# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sbn

# %%
dataFrame = pd.read_csv("kc_house_data.csv")

# %%
dataFrame.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
dataFrame.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
dataFrame = dataFrame.drop("id", axis = 1)

# %%
dataFrame
# Out:
#                   date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      20141013T000000  221900.0         3       1.00         1180      5650
# 1      20141209T000000  538000.0         3       2.25         2570      7242
# 2      20150225T000000  180000.0         2       1.00          770     10000
# 3      20141209T000000  604000.0         4       3.00         1960      5000
# 4      20150218T000000  510000.0         3       2.00         1680      8080
# ...                ...       ...       ...        ...          ...       ...
# 21608  20140521T000000  360000.0         3       2.50         1530      1131
# 21609  20150223T000000  400000.0         4       2.50         2310      5813
# 21610  20140623T000000  402101.0         2       0.75         1020      1350
# 21611  20150116T000000  400000.0         3       2.50         1600      2388
# 21612  20141015T000000  325000.0         2       0.75         1020      1076
#
# ...

# %%
for n in list(range(len(dataFrame["date"]))):
    dataFrame["date"][n] = dataFrame["date"][n][:4]
# Out:
# /var/folders/mh/x5vmc6194szf246rdvs1s6n40000gn/T/ipykernel_14762/4162065513.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataFrame["date"][n] = dataFrame["date"][n][:4]

# %%
dataFrame.head(10)
# Out:
#    date      price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  2014   221900.0         3       1.00         1180      5650     1.0
# 1  2014   538000.0         3       2.25         2570      7242     2.0
# 2  2015   180000.0         2       1.00          770     10000     1.0
# 3  2014   604000.0         4       3.00         1960      5000     1.0
# 4  2015   510000.0         3       2.00         1680      8080     1.0
# 5  2014  1225000.0         4       4.50         5420    101930     1.0
# 6  2014   257500.0         3       2.25         1715      6819     2.0
# 7  2015   291850.0         3       1.50         1060      9711     1.0
# 8  2015   229500.0         3       1.00         1780      7470     1.0
# 9  2015   323000.0         3       2.50         1890      6560     2.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# ...

# %%
dataFrame.isnull().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
sbn.displot(dataFrame["price"])

# %%
sbn.displot(dataFrame["date"])

# %%
dataFrame.drop("zipcode",axis=1,inplace = True)

# %%
dataFrame.corr().sort_values(by=["price"])
# Out:
#                   price  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# long           0.021626  0.129473   0.223042     0.240223  0.229521  0.125419
# condition      0.036362  0.028472  -0.124982    -0.058753 -0.008958 -0.263768
# yr_built       0.054012  0.154178   0.506019     0.318049  0.053080  0.489319
# sqft_lot15     0.082447  0.029244   0.087175     0.183286  0.718557 -0.011269
# sqft_lot       0.089661  0.031703   0.087740     0.172826  1.000000 -0.005201
# yr_renovated   0.126434  0.018841   0.050739     0.055363  0.007644  0.006338
# floors         0.256794  0.175429   0.500653     0.353949 -0.005201  1.000000
# waterfront     0.266369 -0.006582   0.063744     0.103818  0.021604  0.023698
# lat            0.307003 -0.008931   0.024573     0.052529 -0.085683  0.049614
# bedrooms       0.308350  1.000000   0.515884     0.576671  0.031703  0.175429
# sqft_basement  0.323816  0.303093   0.283770     0.435043  0.015286 -0.245705
# ...

# %%
sbn.scatterplot(x = "sqft_living", y= "price", data = dataFrame)
# Out:
# <AxesSubplot:xlabel='sqft_living', ylabel='price'>

# %%
dataFrame.sort_values("price",ascending=False).head(10)
# Out:
#       date      price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 7252  2014  7700000.0         6       8.00        12050     27600     2.5
# 3914  2014  7062500.0         5       4.50        10040     37325     2.0
# 9254  2014  6885000.0         6       7.75         9890     31374     2.0
# 4411  2014  5570000.0         5       5.75         9200     35069     2.0
# 1448  2015  5350000.0         5       5.00         8000     23985     2.0
# 1315  2015  5300000.0         6       6.00         7390     24829     2.0
# 1164  2014  5110800.0         5       5.25         8010     45517     2.0
# 8092  2014  4668000.0         5       6.75         9640     13068     1.0
# 2626  2014  4500000.0         5       5.50         6640     40014     2.0
# 8638  2014  4489000.0         4       3.00         6430     27517     2.0
#
#       waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# ...

# %%
nDataFrame = dataFrame.sort_values("price",ascending=False).iloc[6:]

# %%
nDataFrame.sort_values("price",ascending=False)
# Out:
#        date      price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 1164   2014  5110800.0         5       5.25         8010     45517     2.0
# 8092   2014  4668000.0         5       6.75         9640     13068     1.0
# 2626   2014  4500000.0         5       5.50         6640     40014     2.0
# 8638   2014  4489000.0         4       3.00         6430     27517     2.0
# 12370  2015  4208000.0         5       6.00         7440     21540     2.0
# ...     ...        ...       ...        ...          ...       ...     ...
# 8274   2014    82000.0         3       1.00          860     10426     1.0
# 16198  2015    81000.0         2       1.00          730      9975     1.0
# 465    2014    80000.0         1       0.75          430      5050     1.0
# 15293  2014    78000.0         2       1.00          780     16344     1.0
# 1149   2015    75000.0         1       0.00          670     43377     1.0
#
# ...

# %%
plt.subplot(2,1,1)
plt.hist(dataFrame["price"])

plt.subplot(2,1,2)
plt.hist(nDataFrame["price"])
# Out:
# (array([1.4753e+04, 5.6110e+03, 7.9800e+02, 2.6100e+02, 1.0600e+02,
#         4.2000e+01, 2.2000e+01, 9.0000e+00, 3.0000e+00, 2.0000e+00]),
#  array([  75000.,  578580., 1082160., 1585740., 2089320., 2592900.,
#         3096480., 3600060., 4103640., 4607220., 5110800.]),
#  <BarContainer object of 10 artists>)

# %%
sbn.displot(nDataFrame["price"])

# %%
dataFrame.groupby("date").mean()
# Out:
#               price  bedrooms  bathrooms  sqft_living      sqft_lot    floors  \
# date
# 2014  539181.428415  3.377161   2.128904  2098.319073  14950.534272  1.502631
# 2015  541988.992264  3.357593   2.085100  2041.285100  15434.917192  1.476862
#
#       waterfront      view  condition     grade   sqft_above  sqft_basement  \
# date
# 2014    0.007791  0.233582   3.429919  7.681542  1802.015240     296.303834
# 2015    0.007020  0.235817   3.366476  7.605158  1759.827937     281.457163
#
#          yr_built  yr_renovated        lat        long  sqft_living15  \
# date
# 2014  1970.933985     90.978883  47.562848 -122.213923    1996.840498
# 2015  1971.154298     70.614900  47.554192 -122.213841    1964.984527
#
#         sqft_lot15
# date
# 2014  12770.057473
# 2015  12765.097564

# %%
x = nDataFrame.drop("price",axis=1).values
y = nDataFrame["price"].values

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.5)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
x_train = scaler.fit_transform(x_train)

# %%
x_test = scaler.transform(x_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
x_train.shape
# Out:
# (10803, 18)

# %%
model = Sequential()

model.add(Dense(18,activation="relu"))
model.add(Dense(9,activation="relu"))
model.add(Dense(9,activation="relu"))
model.add(Dense(9,activation="relu"))
model.add(Dense(9,activation="relu"))
model.add(Dense(9,activation="relu"))
model.add(Dense(9,activation="relu"))
model.add(Dense(9,activation="relu"))
model.add(Dense(9,activation="relu"))
model.add(Dense(9,activation="relu"))
model.add(Dense(9,activation="relu"))
model.add(Dense(5,activation="relu"))
model.add(Dense(5,activation="relu"))

model.add(Dense(1))

model.compile(optimizer="adam",loss="mse")

# %%
model.fit(x=x_train,y=y_train,epochs=1000,validation_data=(x_test,y_test))
# Out:
# Epoch 1/1000
# 338/338 [==============================] - 1s 1ms/step - loss: 257523105792.0000 - val_loss: 92342001664.0000
# Epoch 2/1000
# 338/338 [==============================] - 0s 1ms/step - loss: 73329238016.0000 - val_loss: 74822402048.0000
# Epoch 3/1000
# 338/338 [==============================] - 0s 1ms/step - loss: 54690054144.0000 - val_loss: 51823734784.0000
# Epoch 4/1000
# 338/338 [==============================] - 0s 1ms/step - loss: 43480596480.0000 - val_loss: 47590490112.0000
# Epoch 5/1000
# 338/338 [==============================] - 0s 1ms/step - loss: 39913914368.0000 - val_loss: 46047891456.0000
# Epoch 6/1000
# 338/338 [==============================] - 0s 1ms/step - loss: 37566562304.0000 - val_loss: 39632494592.0000
# Epoch 7/1000
# 338/338 [==============================] - 0s 1ms/step - loss: 35208511488.0000 - val_loss: 37680025600.0000
# Epoch 8/1000
# ...

# %%
first_lossData = pd.DataFrame(model.history.history)
first_lossData.head()
# Out:
#            loss      val_loss
# 0  3.090268e+10  3.345419e+10
# 1  3.084781e+10  3.328100e+10
# 2  3.081759e+10  3.317209e+10
# 3  3.080982e+10  3.314191e+10
# 4  3.068640e+10  3.349380e+10

# %%
first_lossData.plot()
# Out:
# <AxesSubplot:>

# %%
second_dataLoss = pd.DataFrame(model.history.history)
second_dataLoss.head(5)
# Out:
#            loss      val_loss
# 0  2.575231e+11  9.234200e+10
# 1  7.332924e+10  7.482240e+10
# 2  5.469005e+10  5.182373e+10
# 3  4.348060e+10  4.759049e+10
# 4  3.991391e+10  4.604789e+10

# %%
second_dataLoss.plot()
# Out:
# <AxesSubplot:>

# %%
predictSeries = model.predict(x_test)
# Out:
# 338/338 [==============================] - 0s 414us/step

# %%
plt.scatter(y_test,predictSeries)
plt.plot(y_test,y_test,"r-")
